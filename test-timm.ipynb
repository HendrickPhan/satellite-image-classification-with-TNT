# %%
# !pip install torch timm

# %%
# !pip uninstall torch torchvision -y
# Out:
# Found existing installation: torch 2.1.0.dev20230311
# Uninstalling torch-2.1.0.dev20230311:
#   Successfully uninstalled torch-2.1.0.dev20230311
# Found existing installation: torchvision 0.14.1
# Uninstalling torchvision-0.14.1:
#   Successfully uninstalled torchvision-0.14.1

# %%
# !pip install --pre torch torchvision --extra-index-url https://download.pytorch.org/whl/nightly/cpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/nightly/cpu
# ...
#   Using cached https://download.pytorch.org/whl/nightly/cpu/torch-2.1.0.dev20230311-cp39-none-macosx_11_0_arm64.whl (56.3 MB)
# ...
#      |████████████████████████████████| 1.5 MB 231 kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/hieuphandinhminh/Desktop/Repo/Python/test-timm/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
import torch
print(torch.__version__)
torch.has_mps
# Out:
# 2.1.0.dev20230311
# True

# %%
# !git clone https://github.com/rwightman/pytorch-image-models

# %%
# %cd pytorch-image-models 
# !pip install -e .
# Out:
# /Users/hieuphandinhminh/Desktop/Repo/Python/test-timm/pytorch-image-models
# Obtaining file:///Users/hieuphandinhminh/Desktop/Repo/Python/test-timm/pytorch-image-models
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Attempting uninstall: timm
#     Found existing installation: timm 0.8.15.dev0
#     Uninstalling timm-0.8.15.dev0:
#       Successfully uninstalled timm-0.8.15.dev0
#   Running setup.py develop for timm
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/hieuphandinhminh/Desktop/Repo/Python/test-timm/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
# !python train.py ../Satellite --model tnt_s_patch16_224 -b 32 --sched step --epochs 50 --resume "output/train/20230311-215251-tnt_s_patch16_224-224/checkpoint-1.pth.tar" --num-classes 4
# !python train.py ../Satellite --model tnt_s_patch16_224 -b 32 --sched step --epochs 50  --num-classes 4
# Out:
# Training with a single process on 1 device (mps).
# Model tnt_s_patch16_224 created, param count:23371876
# Data processing configuration for current model + dataset:
# 	input_size: (3, 224, 224)
# 	interpolation: bicubic
# 	mean: (0.5, 0.5, 0.5)
# 	std: (0.5, 0.5, 0.5)
# 	crop_pct: 0.9
# 	crop_mode: center
# Learning rate (0.0125) calculated from base learning rate (0.1) and global batch size (32) with linear scaling.
# AMP not enabled. Training in float32.
# Scheduled epochs: 50. LR stepped per epoch.
# /Users/hieuphandinhminh/Desktop/Repo/Python/test-timm/venv/lib/python3.9/site-packages/torch/nn/functional.py:4702: UserWarning: The operator 'aten::im2col' is not currently supported on the MPS backend and will fall back to run on the CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/mps/MPSFallback.mm:12.)
# ...
